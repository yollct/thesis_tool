# %%
import pandas as pd
import numpy as np

# %%
oxi_gene = pd.read_excel("/home/chit/Desktop/Thesis/data/4timepoints/GeneListed_Oxi_Repair.xlsx")
oxi_gene[['ID']]
# Out:
#         ID
# 0   DHCR24
# 1    BNIP3
# 2     CCL5
# 3    MPV17
# 4     NQO1
# ..     ...
# 65  TXNRD2
# 66     TXN
# 67     TPO
# 68     TTN
# 69    UCP2
#
# [70 rows x 1 columns]

# %%
clusters = pd.read_csv("/home/chit/Desktop/Thesis/results/05.08/cluster_table.csv")
filter1 = clusters[clusters['object'].isin(oxi_gene['ID'])].cluster.unique()

# %%
with open("/home/chit/Desktop/Thesis/results/05.08/all_connect.txt") as f:
    connect = f.read().split("\n")
# Out:
# <generator object <genexpr> at 0x7f6c022481b0>

# %%
logodd_cluster = []
for a in connect:
    split = a.split("_")
    for b in split:
        c = "Cluster "+ b
        if c not in logodd_cluster:
            logodd_cluster.append(c)

# %%
##filter the clusters and oxi gene list
highlogodd = clusters[clusters['cluster'].isin(logodd_cluster)]
gene_list = highlogodd[highlogodd['object'].isin(oxi_gene['ID'])].object.to_list()

# %%
##bg list = clusters in highlogodd
bg = highlogodd.object.to_list()
bg
# Out:
# ['HMCES',
#  'TMED1',
#  'NDUFS7',
#  'MINOS1',
#  'ZCCHC4',
#  'FOXP4',
#  'LGR5',
#  'ZNF274',
#  'TKFC',
#  'HACD1',
#  'METTL23',
#  'CREM',
#  'EXOSC9',
#  'ERCC8',
#  'C1orf109',
#  'PRELID1',
#  'NME3',
#  'PTCD1',
#  'MYCBP',
#  'COPS9',
#  'SEPSECS',
#  'TMEM204',
#  'UNC119',
#  'MAGEF1',
#  'ALKBH7',
#  'COQ6',
#  'MRPL52',
#  'TMEM141',
#  'ZNF785',
#  'ZNF350',
#  'HNRNPA1L2',
#  'NOCT',
#  'PPIEL',
#  'IL15RA',
#  'PPIP5K1',
#  'CHST7',
#  'ALG10B',
#  'TIMM21',
#  'IFT22',
#  'LSM7',
#  'ZNF17',
#  'ACOT7',
#  'LSM10',
#  'C5orf56',
#  'PDPN',
#  'RPL23P8',
#  'PUDP',
#  'CLPP',
#  'URB2',
#  'D2HGDH',
#  'COMMD5',
#  'HIC2',
#  'ARV1',
#  'RMDN2',
#  'GAS8',
#  'IFI35',
#  'CCDC18',
#  'STRBP',
#  'CHST2',
#  'LOC100507387',
#  'ARID5A',
#  'DNAJC4',
#  'LOC645166',
#  'MEMO1',
#  'C20orf27',
#  'INTS6L',
#  'OGG1',
#  'RRNAD1',
#  'CD27-AS1',
#  'CYTL1',
#  'LDOC1',
#  'ZNF439',
#  'LINC01184',
#  'BRSK1',
#  'ARMC5',
#  'METRN',
#  'RBFA',
#  'FAM109A',
#  'OTUD6B',
#  'TRMT44',
#  'VPS37C',
#  'DDX19B',
#  'CYTOR',
#  'CPT2',
#  'BHLHB9',
#  'CEP41',
#  'LINC00856',
#  'TATDN1',
#  'TFB2M',
#  'KCTD21',
#  'RABL2B',
#  'RPL41',
#  'LINC00630',
#  'RASGRP3',
#  'HTR2B',
#  'CCKAR',
#  'C22orf39',
#  'CRIPAK',
#  'MRM3',
#  'CPEB1',
#  'CEP83',
#  'SCAND1',
#  'MED26',
#  'RNF215',
#  'STX10',
#  'TMEM14EP',
#  'SNX24',
#  'PLPP7',
#  'RGMA',
#  'ZNF354A',
#  'TBP',
#  'PIGC',
#  'AKTIP',
#  'TMEM241',
#  'ASPSCR1',
#  'BEST1',
#  'GAREM2',
#  'STOML1',
#  'ZNF788',
#  'VAMP1',
#  'ZFYVE28',
#  'QTRT2',
#  'KCNJ13',
#  'PNKD',
#  'SLC16A5',
#  'MED25',
#  'METTL5',
#  'RIDA',
#  'BLOC1S3',
#  'RRP1',
#  'DCLRE1C',
#  'ARPC5L',
#  'HMGN3',
#  'DAGLA',
#  'TRMU',
#  'PRUNE1',
#  'TMEM234',
#  'MRPL16',
#  'XYLB',
#  'C14orf1',
#  'TRIM52',
#  'NDUFA2',
#  'NDUFA3',
#  'PPM1H',
#  'EP400NL',
#  'CCDC86',
#  'PAK4',
#  'DUSP22',
#  'BMS1P20',
#  'ZNF177',
#  'NBEAL2',
#  'ARHGEF37',
#  'C17orf49',
#  'RFXANK',
#  'BTN2A2',
#  'TAZ',
#  'TAF6L',
#  'WBP4',
#  'PAXIP1',
#  'PRMT3',
#  'GSKIP',
#  'TDRD7',
#  'KIAA1328',
#  'HSPE1',
#  'HPRT1',
#  'ZNF267',
#  'TMEM201',
#  'PIGB',
#  'WDR5B',
#  'IBA57',
#  'COX14',
#  'CDKL5',
#  'TMEM208',
#  'HMBS',
#  'GSPT2',
#  'MAP1LC3A',
#  'FN3KRP',
#  'RPL22L1',
#  'ZNF438',
#  'ZNF701',
#  'TRIM68',
#  'TRAPPC2L',
#  'TMEM14A',
#  'SLX4',
#  'KIAA1671',
#  'MOSPD1',
#  'PXMP4',
#  'TACO1',
#  'ZNF829',
#  'ARRDC2',
#  'ZNF671',
#  'BLOC1S5',
#  'SLC36A4',
#  'BCL2',
#  'CXorf40B',
#  'FUT4',
#  'NCKIPSD',
#  'SCNM1',
#  'BMS1P4',
#  'TGFB3',
#  'CCDC125',
#  'GPN2',
#  'MTERF2',
#  'FAM175A',
#  'FES',
#  'ANKRD6',
#  'PLEKHG6',
#  'KDELC1',
#  'BAIAP2',
#  'DAPK2',
#  'ACY1',
#  'ZNF607',
#  'FAM222B',
#  'PRRT3',
#  'RTL1',
#  'DUS3L',
#  'PTRH2',
#  'KRBA1',
#  'MMP24',
#  'TUBG2',
#  'GTF3C6',
#  'DCUN1D2',
#  'ANO3',
#  'ELOF1',
#  'DUSP12',
#  'ZSWIM1',
#  'WDR18',
#  'DONSON',
#  'CCNJ',
#  'FHL3',
#  'PAAF1',
#  'TDP1',
#  'NLE1',
#  'KAT8',
#  'MRPL33',
#  'COMMD10',
#  'MRPL11',
#  'IL6R',
#  'HAUS4',
#  'OSGIN1',
#  'OTUD6B-AS1',
#  'C5orf30',
#  'LINC01278',
#  'SND1-IT1',
#  'LOC729086',
#  'ETFRF1',
#  'INTS9',
#  'PALB2',
#  'ANKAR',
#  'TMEM182',
#  'SYT14',
#  'ZNF584',
#  'NOP14-AS1',
#  'FBXO45',
#  'NUDT18',
#  'CPT1C',
#  'KTI12',
#  'LMCD1',
#  'PPP1R16A',
#  'ZBTB39',
#  'EIF4E',
#  'CHMP4A',
#  'PRMT9',
#  'TRAF2',
#  'ACBD4',
#  'ZFP1',
#  'TMEM243',
#  'KIAA0895L',
#  'ZNF419',
#  'DNAJB5',
#  'COA7',
#  'PODXL',
#  'MIS12',
#  'GLMN',
#  'MALSU1',
#  'TYMP',
#  'NAAA',
#  'UBL7',
#  'GTF2E1',
#  'PLP2',
#  'DBR1',
#  'LOC100506548',
#  'PELI3',
#  'ZNF75A',
#  'HAGH',
#  'USB1',
#  'HAPLN1',
#  'RHNO1',
#  'CELF2',
#  'PLA2G6',
#  'SIRT6',
#  'NFU1',
#  'TSFM',
#  'SPAG16',
#  'AFG3L1P',
#  'NUDT12',
#  'NAGPA',
#  'MRPL27',
#  'SLC25A20',
#  'ZNF606',
#  'FAM76A',
#  'SORCS2',
#  'MMAA',
#  'SHC2',
#  'AADAT',
#  'CRY1',
#  'VKORC1L1',
#  'HOMER1',
#  'GUSBP1',
#  'ZSCAN22',
#  'TMEM11',
#  'ASAP1-IT1',
#  'SERGEF',
#  'RASGRF2',
#  'NR5A2',
#  'GPATCH4',
#  'PPP1R26',
#  'CRYBB2P1',
#  'APOBEC3F',
#  'LOC100129917',
#  'PIM3',
#  'RBM8A',
#  'ARG2',
#  'ZNF10',
#  'MRPS33',
#  'C6orf1',
#  'FLAD1',
#  'BRMS1',
#  'SAP30',
#  'NME1',
#  'SWT1',
#  'R3HCC1',
#  'RPL13A',
#  'GDPD5',
#  'RFX2',
#  'LOC283922',
#  'QTRT1',
#  'PRDM15',
#  'PARP12',
#  'TADA2A',
#  'ZNF595',
#  'ZNF138',
#  'ZNF174',
#  'MIR31HG',
#  'XRCC1',
#  'TMEM62',
#  'FOXRED1',
#  'PCGF1',
#  'PIGM',
#  'RNF138',
#  'ZFP82',
#  'DCLRE1A',
#  'FUK',
#  'ZNF526',
#  'ADAMTS13',
#  'RGS11',
#  'HDAC10',
#  'JOSD2',
#  'TRIM21',
#  'UCK2',
#  'CWC27',
#  'TEPSIN',
#  'TMEM18',
#  'DUOX1',
#  'TTC12',
#  'EFCAB13',
#  'SF3A2',
#  'RAB27A',
#  'SLC18A2',
#  'ABHD8',
#  'TAF3',
#  'TMEM117',
#  'IQCG',
#  'ZNF765',
#  'TMEM128',
#  'GFER',
#  'DTNB',
#  'ZNF692',
#  'GLI2',
#  'PLEKHJ1',
#  'ZNF787',
#  'SPATA7',
#  'LPXN',
#  'CCDC142',
#  'C11orf54',
#  'ZNF354B',
#  'CNNM4',
#  'SGK3',
#  'SMIM19',
#  'LBHD1',
#  'FKBP2',
#  'HINFP',
#  'CPNE7',
#  'AGTRAP',
#  'MAP3K10',
#  'WDCP',
#  'SLC39A3',
#  'DEPDC7',
#  'OXNAD1',
#  'TMPPE',
#  'HSF2',
#  'SLC10A7',
#  'MRPS26',
#  'SLC9B2',
#  'ACAD8',
#  'NDUFAF3',
#  'USP21',
#  'PDSS2',
#  'MTERF1',
#  'B3GNT2',
#  'TRMT61B',
#  'C19orf25',
#  'ENOX2',
#  'SIRT3',
#  'ZNF235',
#  'TYW5',
#  'ARRDC1',
#  'HADH',
#  'GPSM2',
#  'BCKDHA',
#  'PCDHB13',
#  'PACRGL',
#  'SNAPC2',
#  'SNCA',
#  'ZNF415',
#  'KLF16',
#  'UBIAD1',
#  'THAP7',
#  'MINDY4',
#  'TOM1L1',
#  'ULK4',
#  'MAPK11',
#  'SPTBN4',
#  'DPH7',
#  'SNX11',
#  'ZDHHC24',
#  'PLEKHF2',
#  'PSMD6-AS2',
#  'RPUSD1',
#  'PQLC2',
#  'PROCR',
#  'ATP2A3',
#  'ELFN1',
#  'FADD',
#  'LACTB2',
#  'PPARGC1A',
#  'TTLL11',
#  'HSPBP1',
#  'RAB36',
#  'PGAP2',
#  'ZNF589',
#  'TMEM205',
#  'MRPL40',
#  'ZNF79',
#  'ALG1',
#  'CGRRF1',
#  'AGPAT5',
#  'ABT1',
#  'HDHD5',
#  'ELP6',
#  'LOC100506031',
#  'PPP4R1L',
#  'FBRSL1',
#  'ECHDC2',
#  'TRPT1',
#  'DACT3',
#  'TRIM62',
#  'OGFOD2',
#  'SLC18B1',
#  'PAFAH2',
#  'CLPB',
#  'SUSD5',
#  'SRD5A3',
#  'SP4',
#  'STK11IP',
#  'ACTR6',
#  'NCAPG2',
#  'C19orf66',
#  'LINC00597',
#  'TOMM40',
#  'MTRF1L',
#  'P2RX7',
#  'SMIM20',
#  'PSTPIP2',
#  'NARS2',
#  'DDX51',
#  'MAP7',
#  'TXNRD2',
#  'PARP2',
#  'MRPL39',
#  'CLN6',
#  'ZNF707',
#  'METTL22',
#  'RNF166',
#  'TMEM150A',
#  'ANGPTL4',
#  'SLC46A3',
#  'DGCR14',
#  'CAAP1',
#  'TRMT2B',
#  'ZNF304',
#  'LINC00847',
#  'ABHD17C',
#  'WDR90',
#  'TTC5',
#  'TNFAIP6',
#  'CDADC1',
#  'TCTN2',
#  'LYPLA2',
#  'POLR1C',
#  'PANK4',
#  'HTRA2',
#  'TAPBPL',
#  'NEIL2',
#  'PRRT2',
#  'TMEM69',
#  'MAD2L2',
#  'SHF',
#  'CDKN1C',
#  'C22orf46',
#  'ZNF112',
#  'PA2G4P4',
#  'ABCC9',
#  'ERICH1',
#  'C1orf174',
#  'CACNB1',
#  'IFIT2',
#  'SNORD89',
#  'ID1',
#  'PCDHB16',
#  'ATL1',
#  'LINC00476',
#  'NSMCE4A',
#  'PPAT',
#  'ORC5',
#  'TERC',
#  'CENPN',
#  'CORO7',
#  'ECI1',
#  'ZFAND2B',
#  'TBC1D10A',
#  'SIAH1',
#  'RDH14',
#  'TGDS',
#  'CHST12',
#  'SMYD2',
#  'CACTIN',
#  'CENPJ',
#  'COMMD8',
#  'PTCD2',
#  'C8orf76',
#  'MRPL22',
#  'TBCE',
#  'KAZALD1',
#  'USP30',
#  'APBA2',
#  'PRTFDC1',
#  'DTD1',
#  'TMEM242',
#  'CLCN4',
#  'ARHGAP19',
#  'CYSTM1',
#  'POLR3F',
#  'SPDL1',
#  'TCEA2',
#  'ZNF615',
#  'MCM4',
#  'SPHK2',
#  'BANP',
#  'FLYWCH2',
#  'C9orf64',
#  'GADD45B',
#  'TECR',
#  'UQCC2',
#  'CD40',
#  'SCRN2',
#  'GMCL1',
#  'RCC1L',
#  'OTUD1',
#  'ZBTB8OS',
#  'CRYZL1',
#  'PAQR5',
#  'PENK',
#  'TTC9C',
#  'CYB5D1',
#  'HYPK',
#  'C7orf43',
#  'TARBP2',
#  'LOC388692',
#  'FBXO41',
#  'PIPSL',
#  'METTL2A',
#  'FAM76B',
#  'ZNF845',
#  'TGIF2',
#  'EFCAB7',
#  'KLHL11',
#  'FNDC1',
#  'PCDHGA8',
#  'FSIP2',
#  'OSGEPL1',
#  'MED9',
#  'LETM2',
#  'ISG15',
#  'PCDHGA3',
#  'L3MBTL2',
#  'DNAH7',
#  'SUMO1P3',
#  'JPX',
#  'NDUFAF7',
#  'ZNF329',
#  'TCEAL1',
#  'GLCCI1',
#  'ZNF134',
#  'ID3',
#  'SELENOK',
#  'KLHDC1',
#  'SHISA4',
#  'CDKN2C',
#  'ZNF287',
#  'C19orf70',
#  'PCDHGA2',
#  'KCND3',
#  'KAT14',
#  'THUMPD3-AS1',
#  'MTMR7',
#  'ARL13B',
#  'DIAPH3',
#  'ZNF616',
#  'GPX7',
#  'LOC153684',
#  'EGR3',
#  'RPL9',
#  'KLHL3',
#  'ARL10',
#  'ARHGEF19',
#  'SLC38A4',
#  'RNF8',
#  'MDM1',
#  'FLI1',
#  'SFMBT1',
#  'TUBG1',
#  'FAM206A',
#  'ZNF555',
#  'LMLN',
#  'NDUFS6',
#  'TMEM183A',
#  'ANKRD54',
#  'COL6A6',
#  'TATDN3',
#  'TSSC1',
#  'PAQR3',
#  'NDOR1',
#  'ARMCX5',
#  'C5',
#  'MSANTD2',
#  'TMEM267',
#  'HMGB3',
#  'ICAM1',
#  'MRPL1',
#  'TMEM70',
#  'CEP57L1',
#  'FER1L4',
#  'ZUFSP',
#  'HAUS7',
#  'SNORA8',
#  'NEMP2',
#  'PHLPP1',
#  'H3F3AP4',
#  'MVD',
#  'C15orf59',
#  'ACVR2B',
#  'RNF135',
#  'FAM210A',
#  'ZNF181',
#  'RGS10',
#  'MRPL14',
#  'UPRT',
#  'ZNF92',
#  'CLIC2',
#  'EEFSEC',
#  'HDAC11',
#  'ZBTB37',
#  'TMEM199',
#  'KIAA1755',
#  'FMO4',
#  'C11orf63',
#  'EMC8',
#  'POC1B',
#  'ZNF132',
#  'TTC30A',
#  'RPF2',
#  'PFDN4',
#  'MIPOL1',
#  'FARS2',
#  'MRPL35',
#  'GPRASP2',
#  'UBE2Q2P1',
#  'CKS2',
#  'BPHL',
#  'THYN1',
#  'CRACR2A',
#  'ARVCF',
#  'ERO1B',
#  'GALNT15',
#  'BOK',
#  'LYSMD4',
#  'NABP2',
#  'CINP',
#  'ARL16',
#  'PWARSN',
#  'ZNF175',
#  'SMAD9',
#  'TOP1MT',
#  'RAB15',
#  'ZNF35',
#  'IFT88',
#  'IQCB1',
#  'SP110',
#  'DALRD3',
#  'CASP1',
#  'PMF1',
#  'PRPF40B',
#  'C10orf88',
#  'TRIM47',
#  'CACNB3',
#  'ZNF714',
#  'C21orf2',
#  'TXNDC17',
#  'NOD1',
#  'TIMM8B',
#  'ADCY1',
#  'LOC730102',
#  'NHSL1',
#  'TRDMT1',
#  'ZNF250',
#  'RBM45',
#  'FAM229B',
#  'GALK1',
#  'TMLHE',
#  'CACNA1A',
#  'CARD19',
#  'BHMT2',
#  'CHAC1',
#  'TARS2',
#  'FOXO3B',
#  'PMVK',
#  'C19orf60',
#  'LINC00998',
#  'KIAA0825',
#  'SNORA57',
#  'ANKRD13B',
#  'MIR4435-2HG',
#  'GSTM2',
#  'FAM45A',
#  'TRPV2',
#  'TMEM59L',
#  'INTU',
#  'TRIM11',
#  'PRPF31',
#  'REL',
#  'TBC1D25',
#  'MAP3K11',
#  'TBCCD1',
#  'CAPN3',
#  'LRRC32',
#  'MRPL41',
#  'ZNF546',
#  'B3GLCT',
#  'CHMP6',
#  'RAD51D',
#  'XPA',
#  'AUTS2',
#  'DYNC2LI1',
#  'FAM49B',
#  'RNF138P1',
#  'ADAM19',
#  'ZNF543',
#  'ALDH6A1',
#  'ZNF107',
#  'BEND6',
#  'RTKN',
#  'CCDC9',
#  'MTMR9LP',
#  'MSRB2',
#  'TMEM161B',
#  'MEIS1',
#  'WDR74',
#  'LRP8',
#  'PCDHB14',
#  'NUBPL',
#  'RPS6KB2',
#  'CCDC84',
#  'NIF3L1',
#  'SKAP2',
#  'EVA1A',
#  'SLC43A2',
#  'SUPT4H1',
#  'NKAP',
#  'RASD1',
#  'EBPL',
#  'RFT1',
#  'NBPF14',
#  'ACOT8',
#  'SSX2IP',
#  'RMI1',
#  'ZNF468',
#  'SLC25A26',
#  'TCEANC2',
#  'ZFP14',
#  'HCCS',
#  'SNORA7B',
#  'MTFR1',
#  'HAUS3',
#  'SPIN4',
#  'PHF5A',
#  'ZNF551',
#  'ARRB1',
#  'LRRC57',
#  'QDPR',
#  'APOL3',
#  'ACYP1',
#  'B3GAT3',
#  'ZNF44',
#  'SLC25A40',
#  'BBS5',
#  'NT5C',
#  'UMAD1',
#  'TRUB2',
#  'NAA38',
#  'CCDC71',
#  'ZNF844',
#  'TRMT10C',
#  'DMAP1',
#  'TAPT1-AS1',
#  'RNFT1',
#  'LINC00654',
#  'LOC100130027',
#  'C11orf49',
#  'LYRM4',
#  'ST7',
#  'ZNF678',
#  'TMEM198B',
#  'TMEM200B',
#  'CCDC102A',
#  'TIMM23',
#  'PCDHGC4',
#  'PABPC4L',
#  'FAM136A',
#  'LANCL2',
#  'CDKN2A',
#  'PTGES3',
#  'EXOSC8',
#  'SCARNA16',
#  'ZXDB',
#  'PARP11',
#  'NECTIN1',
#  'SRGAP3',
#  'TMEM26',
#  'PNKP',
#  'MIER2',
#  'ANKRD16',
#  'DKFZP586I1420',
#  'ZNF182',
#  'ARNTL',
#  'DNAJC19',
#  'PCDHGB1',
#  'MOAP1',
#  'RASL12',
#  'IFT74',
#  'PLAT',
#  'SHTN1',
#  'CCS',
#  'NDUFB6',
#  'SNAPC4',
#  'PFDN2',
#  'WWOX',
#  'CRYL1',
#  'INCENP',
#  'SCLT1',
#  'ZNF74',
#  'NME2P1',
#  'BST1',
#  'MRPS2',
#  'CBY1',
#  'ZNF790',
#  'SHROOM1',
#  'ZNF184',
#  'SLC5A6',
#  'TRIB1',
#  'RFX3',
#  'NCAPH2',
#  'FANCM',
#  'MFAP3L',
#  'MARCH1',
#  'RBBP8',
#  'PSMG1',
#  'MRPS14',
#  'FAM98B',
#  'PRC1',
#  'DHX58',
#  'HSPA14',
#  'NUAK1',
#  'SLC35D2',
#  'ZNF525',
#  'MTM1',
#  'COA5',
#  'SMAGP',
#  'NMNAT1',
#  'JUP',
#  'NDUFA12',
#  'TMA16',
#  'LNX2',
#  'NOL3',
#  'LINC01133',
#  'TMEM67',
#  'IKBKE',
#  'SPRTN',
#  'BEX4',
#  'GFPT2',
#  'ENDOV',
#  'FPGT',
#  'KATNB1',
#  'MESDC1',
#  'GAN',
#  'ZWILCH',
#  'GATB',
#  'MED19',
#  'CSRNP1',
#  'FGF13',
#  'TTF2',
#  'RABEPK',
#  'AIP',
#  'TMEM106A',
#  'TRIT1',
#  'CCDC127',
#  'OPHN1',
#  'UBTD1',
#  'ZNF846',
#  'DPH5',
#  'CTC1',
#  'HMGB2',
#  'TMTC4',
#  'SUOX',
#  'CCDC191',
#  'CACNB2',
#  'ZMYND19',
#  'FAM234B',
#  'ARL4A',
#  'ZNF430',
#  'NDUFB3',
#  'EIF5AL1',
#  'NAF1',
#  'NBDY',
#  'TNFSF13B',
#  'BLID',
#  'CASKIN2',
#  'POP1',
#  'CDK8',
#  'ZBTB48',
#  'ABHD10',
#  'GTPBP10',
#  'TSC22D3',
#  'NTNG1',
#  'WASHC2A',
#  'ATOX1',
#  'ZNF614',
#  'IGF2BP3',
#  'ZFPM2',
#  'LY96',
#  'YIPF1',
#  'CCDC144A',
#  'BRCA1',
#  'UCKL1',
#  'FRG1',
#  'ALG11',
#  'COQ8A',
#  'GRK6',
#  'DHFR2',
#  'WDR25',
#  'GUCY1A2',
#  'SALL2',
#  'RNPC3',
#  'NUPL2',
#  'DHRS4-AS1',
#  'ERV3-1',
#  'ZNF429',
#  'ZC3HC1',
#  'GPKOW',
#  'ELOVL6',
#  'C12orf65',
#  'ELOVL4',
#  'ASB13',
#  'SLC4A8',
#  'TTF1',
#  'ZNF736',
#  'CSRP2',
#  'METTL24',
#  'SMYD4',
#  'EDNRA',
#  ...]
